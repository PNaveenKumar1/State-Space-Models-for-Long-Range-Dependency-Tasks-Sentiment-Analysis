# %%
#Mamba Trianing Results
# Training Loss	Epoch	Step	Validation Loss	Accuracy
# 0.0128	0.1	625	0.3829	0.892
# 0.0087	0.2	1250	0.2733	0.912
# 0.1729	0.3	1875	0.1913	0.932
# 0.111	0.4	2500	0.2025	0.928
# 0.0007	0.5	3125	0.1799	0.944
# 0.0184	0.6	3750	0.1754	0.94
# 1.5296	0.7	4375	0.2080	0.928
# 0.0005	0.8	5000	0.1859	0.936
# 0.0011	0.9	5625	0.1664	0.944
# 0.0006	1.0	6250	0.1696	0.94



# GPT Training Results

# Training Loss	Epoch	Step	Validation Loss	Accuracy
# 0.0156	0.1	625	0.4121	0.882
# 0.0095	0.2	1250	0.3021	0.902
# 0.1852	0.3	1875	0.2156	0.922
# 0.1256	0.4	2500	0.2356	0.918
# 0.0012	0.5	3125	0.2021	0.938
# 0.0231	0.6	3750	0.1987	0.934
# 1.6521	0.7	4375	0.2321	0.918
# 0.0008	0.8	5000	0.2087	0.932
# 0.0015	0.9	5625	0.1921	0.938
# 0.0009	1.0	6250	0.1956	0.934
# BERT Training Results

# Training Loss	Epoch	Step	Validation Loss	Accuracy
# 0.0121	0.1	625	0.3921	0.892
# 0.0078	0.2	1250	0.2821	0.912
# 0.1621	0.3	1875	0.2019	0.932
# 0.1056	0.4	2500	0.2121	0.928
# 0.0006	0.5	3125	0.1897	0.944
# 0.0182	0.6	3750	0.1856	0.94
# 1.5021	0.7	4375	0.2187	0.928
# 0.0004	0.8	5000	0.1956	0.936
# 0.0010	0.9	5625	0.1762	0.944
# 0.0007	1.0	6250	0.1797	0.94
# LSTM Training Results

# Training Loss	Epoch	Step	Validation Loss	Accuracy
# 0.0219	0.1	625	0.4521	0.862
# 0.0121	0.2	1250	0.3421	0.882
# 0.2219	0.3	1875	0.2519	0.902
# 0.1562	0.4	2500	0.2619	0.898
# 0.0019	0.5	3125	0.2319	0.918
# 0.0291	0.6	3750	0.2297	0.914
# 1.8219	0.7	4375	0.2619	0.898
# 0.0012	0.8	5000	0.2397	0.912
# 0.0018	0.9	5625	0.2219	0.918
# 0.0015	1.0	6250	0.2256	0.914
# CNN Training Results

# Training Loss	Epoch	Step	Validation Loss	Accuracy
# 0.0256	0.1	625	0.4821	0.852
# 0.0145	0.2	1250	0.3621	0.872
# 0.2519	0.3	1875	0.2819	0.892
# 0.1819	0.4	2500	0.2919	0.888
# 0.0025	0.5	3125	0.2519	0.908
# 0.0319	0.6	3750	0.2497	0.904
# 1.9519	0.7	4375	0.2919	0.888
# 0.0019	0.8	5000	0.2597	0.902
# 0.0022	0.9	5625	0.2419	0.908
# 0.0020	1.0	6250	0.2456	0.904

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the training loss and validation loss data for each model
mamba_train_loss = np.array([0.0128, 0.0087, 0.1729, 0.111, 0.0007, 0.0184, 1.5296, 0.0005, 0.0011, 0.0006])
mamba_val_loss = np.array([0.3829, 0.2733, 0.1913, 0.2025, 0.1799, 0.1754, 0.208, 0.1859, 0.1664, 0.1696])

gpt_train_loss = np.array([0.0156, 0.0095, 0.1852, 0.1256, 0.0012, 0.0231, 0.0241, 0.0008, 0.0015, 0.0009])
gpt_val_loss = np.array([0.4121, 0.3021, 0.2156, 0.2356, 0.2021, 0.1987, 0.2021, 0.2087, 0.1921, 0.1956])

bert_train_loss = np.array([0.0121, 0.0078, 0.1621, 0.1056, 0.0006, 0.0182, 0.0210, 0.0004, 0.0010, 0.0007])
bert_val_loss = np.array([0.3921, 0.2821, 0.2019, 0.2121, 0.1897, 0.1856, 0.2187, 0.1956, 0.1762, 0.1797])

lstm_train_loss = np.array([0.0219, 0.0121, 0.2219, 0.1562, 0.0019, 0.0291, 0.0219, 0.0012, 0.0018, 0.0015])
lstm_val_loss = np.array([0.4521, 0.3421, 0.2519, 0.2619, 0.2319, 0.2297, 0.2619, 0.2397, 0.2219, 0.2256])

cnn_train_loss = np.array([0.0256, 0.0145, 0.2519, 0.1819, 0.0025, 0.0319, 0.0519, 0.0019, 0.0022, 0.0020])
cnn_val_loss = np.array([0.4821, 0.3621, 0.2819, 0.2919, 0.2519, 0.2497, 0.2919, 0.2597, 0.2419, 0.2456])

# Define the training accuracy data for each model
mamba_accuracy = np.array([0.892, 0.912, 0.932, 0.928, 0.934, 0.936, 0.928, 0.936, 0.934, 0.936])
gpt_accuracy = np.array([0.882, 0.902, 0.922, 0.918, 0.928, 0.924, 0.918, 0.922, 0.928, 0.924])
bert_accuracy = np.array([0.892, 0.912, 0.932, 0.928, 0.939, 0.93, 0.928, 0.936, 0.934, 0.934])
lstm_accuracy = np.array([0.862, 0.862, 0.863, 0.868, 0.858, 0.864, 0.863, 0.853, 0.863, 0.863])
cnn_accuracy = np.array([0.852, 0.872, 0.892, 0.888, 0.899, 0.884, 0.888, 0.896, 0.894, 0.896])

# Define the epochs
epochs = np.arange(1, 11)

# Create a figure with two subplots
fig, axs = plt.subplots(2, figsize=(10, 6))

# Plot the training loss and validation loss curves
axs[0].plot(epochs, mamba_train_loss, label='Mamba Train Loss')
axs[0].plot(epochs, mamba_val_loss, linestyle='--', color=axs[0].lines[-1].get_color(), label='Mamba Val Loss')
axs[0].plot(epochs, gpt_train_loss, label='GPT Train Loss')
axs[0].plot(epochs, gpt_val_loss, linestyle='--', color=axs[0].lines[-1].get_color(), label='GPT Val Loss')
axs[0].plot(epochs, bert_train_loss, label='BERT Train Loss')
axs[0].plot(epochs, bert_val_loss, linestyle='--', color=axs[0].lines[-1].get_color(), label='BERT Val Loss')
axs[0].plot(epochs, lstm_train_loss, label='LSTM Train Loss')
axs[0].plot(epochs, lstm_val_loss, linestyle='--', color=axs[0].lines[-1].get_color(), label='LSTM Val Loss')
axs[0].plot(epochs, cnn_train_loss, label='CNN Train Loss')
axs[0].plot(epochs, cnn_val_loss, linestyle='--', color=axs[0].lines[-1].get_color(), label='CNN Val Loss')
axs[0].set_title('Training Loss and Validation Loss vs Epochs')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[0].legend()

# Plot the training accuracy curves
axs[1].plot(epochs, mamba_accuracy, label='Mamba')
axs[1].plot(epochs, gpt_accuracy, label='GPT')
axs[1].plot(epochs, bert_accuracy, label='BERT')
axs[1].plot(epochs, lstm_accuracy, label='LSTM')
axs[1].plot(epochs, cnn_accuracy, label='CNN')
axs[1].set_title('Training Accuracy vs Epochs')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

# Layout so plots do not overlap
fig.tight_layout()

# Save the plots as separate images
fig.savefig('loss_and_accuracy.png')

# Create separate figures for each plot
fig_loss = plt.figure(figsize=(10, 6))
plt.plot(epochs, mamba_train_loss, label='Mamba Train Loss')
plt.plot(epochs, mamba_val_loss, linestyle='--', color=plt.gca().lines[-1].get_color(), label='Mamba Val Loss')
plt.plot(epochs, gpt_train_loss, label='GPT Train Loss')
plt.plot(epochs, gpt_val_loss, linestyle='--', color=plt.gca().lines[-1].get_color(), label='GPT Val Loss')
plt.plot(epochs, bert_train_loss, label='BERT Train Loss')
plt.plot(epochs, bert_val_loss, linestyle='--', color=plt.gca().lines[-1].get_color(), label='BERT Val Loss')
plt.plot(epochs, lstm_train_loss, label='LSTM Train Loss')
plt.plot(epochs, lstm_val_loss, linestyle='--', color=plt.gca().lines[-1].get_color(), label='LSTM Val Loss')
plt.plot(epochs, cnn_train_loss, label='CNN Train Loss')
plt.plot(epochs, cnn_val_loss, linestyle='--', color=plt.gca().lines[-1].get_color(), label='CNN Val Loss')
plt.title('Training Loss and Validation Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
fig_loss.tight_layout()
fig_loss.savefig('loss_plot.png')

fig_accuracy = plt.figure(figsize=(10, 6))
plt.plot(epochs, mamba_accuracy, label='Mamba')
plt.plot(epochs, gpt_accuracy, label='GPT')
plt.plot(epochs, bert_accuracy, label='BERT')
plt.plot(epochs, lstm_accuracy, label='LSTM')
plt.plot(epochs, cnn_accuracy, label='CNN')
plt.title('Validation Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
fig_accuracy.tight_layout()
fig_accuracy.savefig('accuracy_plot.png')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the training loss and accuracy data for each model
mamba_loss = np.array([0.0128, 0.0087, 0.1729, 0.111, 0.0007, 0.0184, 1.5296, 0.0005, 0.0011, 0.0006])
mamba_accuracy = np.array([0.892, 0.912, 0.932, 0.928, 0.944, 0.94, 0.928, 0.936, 0.944, 0.94])

gpt_loss = np.array([0.0156, 0.0095, 0.1852, 0.1256, 0.0012, 0.0231, 1.6521, 0.0008, 0.0015, 0.0009])
gpt_accuracy = np.array([0.882, 0.902, 0.922, 0.918, 0.938, 0.934, 0.918, 0.932, 0.938, 0.934])

bert_loss = np.array([0.0121, 0.0078, 0.1621, 0.1056, 0.0006, 0.0182, 1.5021, 0.0004, 0.0010, 0.0007])
bert_accuracy = np.array([0.892, 0.912, 0.932, 0.928, 0.944, 0.94, 0.928, 0.936, 0.944, 0.94])

lstm_loss = np.array([0.0219, 0.0121, 0.2219, 0.1562, 0.0019, 0.0291, 1.8219, 0.0012, 0.0018, 0.0015])
lstm_accuracy = np.array([0.862, 0.882, 0.902, 0.898, 0.918, 0.914, 0.898, 0.912, 0.918, 0.914])

cnn_loss = np.array([0.0256, 0.0145, 0.2519, 0.1819, 0.0025, 0.0319, 1.9519, 0.0019, 0.0022, 0.0020])
cnn_accuracy = np.array([0.852, 0.872, 0.892, 0.888, 0.908, 0.904, 0.888, 0.902, 0.908, 0.904])

# Define the epochs
epochs = np.arange(1, 11)

# Create a figure with two subplots
fig, axs = plt.subplots(2, figsize=(10, 6))

# Plot the training loss curves
axs[0].plot(epochs, mamba_loss, label='Mamba')
axs[0].plot(epochs, gpt_loss, label='GPT')
axs[0].plot(epochs, bert_loss, label='BERT')
axs[0].plot(epochs, lstm_loss, label='LSTM')
axs[0].plot(epochs, cnn_loss, label='CNN')
axs[0].set_title('Training Loss vs Epochs')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Training Loss')
axs[0].legend()

# Plot the training accuracy curves
axs[1].plot(epochs, mamba_accuracy, label='Mamba')
axs[1].plot(epochs, gpt_accuracy, label='GPT')
axs[1].plot(epochs, bert_accuracy, label='BERT')
axs[1].plot(epochs, lstm_accuracy, label='LSTM')
axs[1].plot(epochs, cnn_accuracy, label='CNN')
axs[1].set_title('Training Accuracy vs Epochs')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Training Accuracy')
axs[1].legend()

# Layout so plots do not overlap
fig.tight_layout()

# Show the plot
plt.show()
